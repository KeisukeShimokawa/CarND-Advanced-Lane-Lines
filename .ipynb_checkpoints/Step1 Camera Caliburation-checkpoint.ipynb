# %%
import cv2
import glob
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
image_paths = glob.glob('./camera_cal/*')
nimage_camera_cal = len(image_paths)
print('#image of camera calburation =', nimage_camera_cal)
# Out:
# #image of camera calburation = 20

# %%
fig, axes = plt.subplots(nrows=5, ncols=4, figsize=(8, 8))
for index, image_path in enumerate(image_paths):
    
    y_index = index // 4
    x_index = index % 4

    img = cv2.imread(image_path)
    
    axes[y_index, x_index].imshow(img)
    axes[y_index, x_index].set_title(image_path.split('/')[2].split('.')[0])
    axes[y_index, x_index].set_xticks([])
    axes[y_index, x_index].set_yticks([])
    
    plt.subplots_adjust(left=0, right=1, bottom=0, top=1)

# %%
img_9 = cv2.imread('./camera_cal/calibration9.jpg')
pts_9 = np.array([[580,50],[550,480],[920,530],[910,220]], np.int32)
pts_9_412 = pts.reshape((-1,1,2))
cv2.polylines(img_9, [pts_9_412], True, (0,255,255), thickness=5)
plt.imshow(img_9)

# %%
test_img = cv2.imread('./camera_cal/calibration1.jpg')
height, width = test_img.shape[:2]

# %%
src = np.array([[0, 0], [width, 0], [height, 0], [height, width]], dtype=np.float32)
dst = np.array([[580, 50], [910, 220], [550, 480], [530, 920]], dtype=np.float32)

# %%
M = cv2.getPerspectiveTransform(src, dst)
test_img_warped = cv2.warpPerspective(test_img, M, dsize=test_img.shape[::-1][1:])

# %%
plt.imshow(test_img_warped)
